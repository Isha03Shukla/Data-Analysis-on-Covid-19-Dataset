# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\KIIT\Downloads\4. covid_19_data.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
sb.heatmap(data.isnull())
plt.show()

# %% [markdown]
# ## Que 1) Show the number of confirmed, death and recovered cases in each Region.

# %%
data.tail(2)
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
data.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby('Region')['Confirmed'].sum().head(50)
# Out:
# Region
# Afghanistan                  1939
# Albania                       766
# Algeria                      3848
# Andorra                       743
# Angola                         27
# Antigua and Barbuda            24
# Argentina                    4285
# Armenia                      1932
# Australia                    6752
# Austria                     15402
# Azerbaijan                   1766
# Bahamas                        80
# Bahrain                      2921
# Bangladesh                   7103
# Barbados                       80
# Belarus                     13181
# Belgium                     47859
# Belize                         18
# Benin                          64
# Bhutan                          7
# Bolivia                      1110
# Bosnia and Herzegovina       1677
# Botswana                       23
# Brazil                      79685
# Brunei                        138
# Bulgaria                     1447
# Burkina Faso                  641
# ...

# %%
data.groupby('Region')['Confirmed','Recovered'].sum()
# Out:
# <ipython-input-25-20fd7b835859>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# Venezuela                 331        142
# Vietnam                   270        222
# West Bank and Gaza        344         71
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [180 rows x 2 columns]

# %% [markdown]
# # Que 2) Remove all the records where Confirmed Cases is less than 10.

# %%
data=data[~(data['Confirmed']<10)]
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# # Que 3)In which top 10 regions, maximum number of confirmed cases were recorded?

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Que 4)In which top 15 regions, minimum number of deaths cases were recorded?

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending=True).head(15)
# Out:
# Region
# Laos                        0
# Mongolia                    0
# Mozambique                  0
# Cambodia                    0
# Fiji                        0
# Namibia                     0
# Nepal                       0
# Madagascar                  0
# Macau                       0
# Papua New Guinea            0
# Rwanda                      0
# Saint Kitts and Nevis       0
# Bhutan                      0
# Dominica                    0
# Central African Republic    0
# Name: Deaths, dtype: int64

# %% [markdown]
# # Que 5)How many confirmed, death & recoverd cases were reported from India till 29 April 2020?

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# # Que 6)Sort the entire data wrt no. of confirmed cases in ascending order.

# %%
data.sort_values(by=['Confirmed'], ascending=True).head(10)
# Out:
#           Date                             State          Region  Confirmed  \
# 285  4/29/2020                         Recovered              US          0
# 284  4/29/2020                         Recovered          Canada          0
# 203  4/29/2020      Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                             Tibet  Mainland China          1
# 289  4/29/2020         Saint Pierre and Miquelon          France          1
# 184  4/29/2020                          Anguilla              UK          3
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba     Netherlands          5
# 272  4/29/2020             Northwest Territories          Canada          5
# 288  4/29/2020                  Saint Barthelemy          France          6
# 178  4/29/2020                               NaN           Yemen          6
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# 305       0          1
# ...

# %% [markdown]
# # Que 7)Sort the entire data wrt no of recovered cases in descending order.

# %%
data.sort_values(by=['Recovered'], ascending=False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]
